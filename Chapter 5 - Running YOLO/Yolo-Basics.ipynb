# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.7-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      -------------------------------------- 40.7/40.7 kB 951.7 kB/s eta 0:00:00
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Using cached matplotlib-3.8.4-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: opencv-python>=4.6.0 in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from ultralytics) (4.9.0.80)
# Collecting pillow>=7.1.2 (from ultralytics)
#   Using cached pillow-10.3.0-cp310-cp310-win_amd64.whl.metadata (9.4 kB)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Using cached scipy-1.13.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.3.0-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.18.0-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from ultralytics) (5.9.8)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting thop>=0.1.1 (from ultralytics)
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Using cached fonttools-4.51.0-cp310-cp310-win_amd64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.21 in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch>=1.8.0->ultralytics)
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: colorama in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics)
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics)
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in f:\tutorial\learn-yolo-object-detection\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.8.0->ultralytics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading ultralytics-8.2.7-py3-none-any.whl (755 kB)
#    ---------------------------------------- 0.0/755.1 kB ? eta -:--:--
#    ------- -------------------------------- 143.4/755.1 kB 4.3 MB/s eta 0:00:01
#    -------------- ------------------------- 266.2/755.1 kB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 604.2/755.1 kB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 755.1/755.1 kB 5.3 MB/s eta 0:00:00
# Using cached matplotlib-3.8.4-cp310-cp310-win_amd64.whl (7.7 MB)
# Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached scipy-1.13.0-cp310-cp310-win_amd64.whl (46.2 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached torch-2.3.0-cp310-cp310-win_amd64.whl (159.8 MB)
# Using cached torchvision-0.18.0-cp310-cp310-win_amd64.whl (1.2 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.51.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: tbb, pytz, py-cpuinfo, mpmath, intel-openmp, urllib3, tzdata, tqdm, sympy, scipy, pyyaml, pyparsing, pillow, networkx, mkl, MarkupSafe, kiwisolver, idna, fsspec, fonttools, filelock, cycler, contourpy, charset-normalizer, certifi, requests, pandas, matplotlib, jinja2, torch, seaborn, torchvision, thop, ultralytics
# Successfully installed MarkupSafe-2.1.5 certifi-2024.2.2 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 filelock-3.14.0 fonttools-4.51.0 fsspec-2024.3.1 idna-3.7 intel-openmp-2021.4.0 jinja2-3.1.3 kiwisolver-1.4.5 matplotlib-3.8.4 mkl-2021.4.0 mpmath-1.3.0 networkx-3.3 pandas-2.2.2 pillow-10.3.0 py-cpuinfo-9.0.0 pyparsing-3.1.2 pytz-2024.1 pyyaml-6.0.1 requests-2.31.0 scipy-1.13.0 seaborn-0.13.2 sympy-1.12 tbb-2021.12.0 thop-0.1.1.post2209072238 torch-2.3.0 torchvision-0.18.0 tqdm-4.66.4 tzdata-2024.1 ultralytics-8.2.7 urllib3-2.2.1

# %%
# !pip list
# Out:
# Package            Version
# ------------------ --------------------
# asttokens          2.4.1
# certifi            2024.2.2
# charset-normalizer 3.3.2
# colorama           0.4.6
# comm               0.2.2
# contourpy          1.2.1
# cycler             0.12.1
# debugpy            1.8.1
# decorator          5.1.1
# exceptiongroup     1.2.1
# executing          2.0.1
# filelock           3.14.0
# fonttools          4.51.0
# fsspec             2024.3.1
# idna               3.7
# intel-openmp       2021.4.0
# ipykernel          6.29.4
# ipython            8.24.0
# jedi               0.19.1
# Jinja2             3.1.3
# jupyter_client     8.6.1
# jupyter_core       5.7.2
# kiwisolver         1.4.5
# MarkupSafe         2.1.5
# matplotlib         3.8.4
# matplotlib-inline  0.1.7
# mkl                2021.4.0
# mpmath             1.3.0
# nest-asyncio       1.6.0
# networkx           3.3
# numpy              1.26.4
# opencv-python      4.9.0.80
# packaging          24.0
# pandas             2.2.2
# parso              0.8.4
# pillow             10.3.0
# pip                24.0
# platformdirs       4.2.1
# prompt-toolkit     3.0.43
# psutil             5.9.8
# pure-eval          0.2.2
# py-cpuinfo         9.0.0
# Pygments           2.17.2
# pyparsing          3.1.2
# python-dateutil    2.9.0.post0
# pytz               2024.1
# pywin32            306
# PyYAML             6.0.1
# pyzmq              26.0.3
# requests           2.31.0
# scipy              1.13.0
# seaborn            0.13.2
# setuptools         65.5.0
# six                1.16.0
# stack-data         0.6.3
# sympy              1.12
# tbb                2021.12.0
# thop               0.1.1.post2209072238
# torch              2.3.0
# torchvision        0.18.0
# tornado            6.4
# tqdm               4.66.4
# traitlets          5.14.3
# typing_extensions  4.11.0
# tzdata             2024.1
# ultralytics        8.2.7
# urllib3            2.2.1
# wcwidth            0.2.13

# %%
from ultralytics import YOLO
import cv2
# Out:
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\agift\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("../YOLO-Weights/yolov8l.pt")
# results = model("images/1.png", show=True)
# results = model("images/2.png", show=True)
# results = model("images/3.png", show=True)
results = model("images/8.jpg", show=True)
cv2.waitKey(0)
# Out:
# image 1/1 f:\Tutorial\learn-yolo-object-detection\Chapter 5 - Running YOLO\images\8.jpg: 384x640 2 persons, 1 motorcycle, 1 bench, 1 dining table, 411.3ms
# Speed: 2.3ms preprocess, 411.3ms inference, 799.6ms postprocess per image at shape (1, 3, 384, 640)
# -1
