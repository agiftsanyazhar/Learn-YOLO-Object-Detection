# %%
from ultralytics import YOLO
from sort import *
import cv2
import cvzone
import math

# %%
cap = cv2.VideoCapture("../Videos/people.mp4")

# %%
model = YOLO("../YOLO-Weights/yolov8l.pt")

classNames = [
    "person",
    "bicycle",
    "car",
    "motorbike",
    "aeroplane",
    "bus",
    "train",
    "truck",
    "boat",
    "traffic light",
    "fire hydrant",
    "stop sign",
    "parking meter",
    "bench",
    "bird",
    "cat",
    "dog",
    "horse",
    "sheep",
    "cow",
    "elephant",
    "bear",
    "zebra",
    "giraffe",
    "backpack",
    "umbrella",
    "handbag",
    "tie",
    "suitcase",
    "frisbee",
    "skis",
    "snowboard",
    "sports ball",
    "kite",
    "baseball bat",
    "baseball glove",
    "skateboard",
    "surfboard",
    "tennis racket",
    "bottle",
    "wine glass",
    "cup",
    "fork",
    "knife",
    "spoon",
    "bowl",
    "banana",
    "apple",
    "sandwich",
    "orange",
    "broccoli",
    "carrot",
    "hot dog",
    "pizza",
    "donut",
    "cake",
    "chair",
    "sofa",
    "pottedplant",
    "bed",
    "diningtable",
    "toilet",
    "tvmonitor",
    "laptop",
    "mouse",
    "remote",
    "keyboard",
    "cell phone",
    "microwave",
    "oven",
    "toaster",
    "sink",
    "refrigerator",
    "book",
    "clock",
    "vase",
    "scissors",
    "teddy bear",
    "hair drier",
    "toothbrush",
]

# %%
mask = cv2.imread("mask.png")

# %%
# Tracking
tracker = Sort(max_age=20, min_hits=3, iou_threshold=0.3)

limitsUp = [103, 161, 296, 161]
limitsDown = [527, 489, 735, 489]

totalCount = 0
totalCountUp = []
totalCountDown = []

# %%
while True:
    success, img = cap.read()
    imgRegion = cv2.bitwise_and(img, mask)

    imgGraphics = cv2.imread(
        "graphics.png", cv2.IMREAD_UNCHANGED
    )
    img = cvzone.overlayPNG(img, imgGraphics, (730, 260))

    results = model(imgRegion, stream=True)

    detections = np.empty((0, 5))

    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100

            # Class Name
            cls = int(box.cls[0])
            currentClass = classNames[cls]

            if currentClass == "person" and conf > 0.3:
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 2)
                currentArray = np.array([x1, y1, x2, y2, conf])
                detections = np.vstack((detections, currentArray))

    resultsTracker = tracker.update(detections)

    cv2.line(
        img, (limitsUp[0], limitsUp[1]), (limitsUp[2], limitsUp[3]), (0, 0, 255), 5
    )
    cv2.line(
        img,
        (limitsDown[0], limitsDown[1]),
        (limitsDown[2], limitsDown[3]),
        (0, 0, 255),
        5,
    )

    for result in resultsTracker:
        x1, y1, x2, y2, id = result
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        w, h = x2 - x1, y2 - y1
        cvzone.putTextRect(
            img,
            f"{int(id)}",
            (max(0, x1), max(35, y1)),
            scale=2,
            thickness=3,
            offset=10,
        )

        cx, cy = x1 + w // 2, y1 + h // 2
        cv2.circle(img, (cx, cy), 5, (255, 0, 255), cv2.FILLED)

        # Count Up
        if limitsUp[0] < cx < limitsUp[2] and limitsUp[1] - 15 < cy < limitsUp[1] + 15:
            if totalCountUp.count(id) == 0:
                totalCountUp.append(id)
                cv2.line(
                    img,
                    (limitsUp[0], limitsUp[1]),
                    (limitsUp[2], limitsUp[3]),
                    (0, 255, 0),
                    5,
                )

        # Count Down
        if (
            limitsDown[0] < cx < limitsDown[2]
            and limitsDown[1] - 15 < cy < limitsDown[1] + 15
        ):
            if totalCountDown.count(id) == 0:
                totalCountDown.append(id)
                cv2.line(
                    img,
                    (limitsDown[0], limitsDown[1]),
                    (limitsDown[2], limitsDown[3]),
                    (0, 255, 0),
                    5,
                )

    totalCount = len(totalCountUp) + len(totalCountDown)

    # Count Up
    cv2.putText(
        img,
        str(len(totalCountUp)),
        (929, 345),
        cv2.FONT_HERSHEY_PLAIN,
        5,
        (139, 195, 75),
        7,
    )

    # Count Down
    cv2.putText(
        img,
        str(len(totalCountDown)),
        (1191, 345),
        cv2.FONT_HERSHEY_PLAIN,
        5,
        (50, 50, 230),
        7,
    )

    # Total Count
    cv2.putText(
        img,
        f"Total: {totalCount}",
        (730, 230),
        cv2.FONT_HERSHEY_PLAIN,
        5,
        (50, 50, 255),
        7,
    )

    cv2.imshow("Image", img)
    # cv2.imshow("ImageRegion", imgRegion)
    cv2.waitKey(1)
# Out:
# 0: 384x640 2 persons, 153.4ms
# Speed: 3.7ms preprocess, 153.4ms inference, 540.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17.8ms
# Speed: 1.1ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 24.5ms
# Speed: 1.8ms preprocess, 24.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17.9ms
# Speed: 1.6ms preprocess, 17.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 19.6ms
# Speed: 1.5ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25.2ms
# Speed: 2.5ms preprocess, 25.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.7ms
# Speed: 1.4ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15.4ms
# Speed: 1.5ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 21.2ms
# Speed: 2.5ms preprocess, 21.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.1ms
# Speed: 1.1ms preprocess, 16.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 22.6ms
# Speed: 1.2ms preprocess, 22.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 23.1ms
# Speed: 1.1ms preprocess, 23.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.0ms
# Speed: 1.3ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 20.9ms
# Speed: 1.3ms preprocess, 20.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23.4ms
# Speed: 1.3ms preprocess, 23.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21.3ms
# Speed: 2.4ms preprocess, 21.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.1ms
# Speed: 1.4ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.3ms
# Speed: 1.5ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.9ms
# Speed: 2.2ms preprocess, 22.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.5ms
# Speed: 1.2ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.6ms
# Speed: 1.1ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.6ms
# Speed: 1.2ms preprocess, 22.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21.1ms
# Speed: 1.4ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.8ms
# Speed: 1.4ms preprocess, 22.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23.6ms
# Speed: 2.5ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.4ms
# Speed: 1.4ms preprocess, 22.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.7ms
# Speed: 1.2ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 15.1ms
# Speed: 2.3ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 20.5ms
# Speed: 1.3ms preprocess, 20.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.0ms
# Speed: 1.2ms preprocess, 23.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 21.9ms
# Speed: 1.7ms preprocess, 21.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 20.4ms
# Speed: 2.2ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.3ms
# Speed: 2.1ms preprocess, 23.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 15.1ms
# Speed: 1.1ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.2ms
# Speed: 1.4ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.9ms
# Speed: 1.5ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 15.5ms
# Speed: 1.3ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 16.7ms
# Speed: 1.1ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.6ms
# Speed: 1.2ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.2ms
# Speed: 0.0ms preprocess, 23.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 15.3ms
# Speed: 1.2ms preprocess, 15.3ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.3ms
# Speed: 1.4ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.3ms
# Speed: 2.6ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 22.8ms
# Speed: 0.5ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.6ms
# Speed: 2.1ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 18.7ms
# Speed: 1.2ms preprocess, 18.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.5ms
# Speed: 1.7ms preprocess, 19.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.6ms
# Speed: 1.4ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.8ms
# Speed: 1.5ms preprocess, 20.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.3ms
# Speed: 1.2ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 1 handbag, 23.1ms
# Speed: 2.5ms preprocess, 23.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 1 handbag, 15.5ms
# Speed: 1.3ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 1 handbag, 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.2ms
# Speed: 2.4ms preprocess, 21.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.1ms
# Speed: 1.3ms preprocess, 22.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.3ms
# Speed: 2.0ms preprocess, 21.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.1ms
# Speed: 1.2ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.0ms
# Speed: 1.4ms preprocess, 22.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 26.3ms
# Speed: 2.1ms preprocess, 26.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.2ms
# Speed: 1.4ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.5ms
# Speed: 1.3ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 1 handbag, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 1 handbag, 17.0ms
# Speed: 1.1ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.4ms
# Speed: 1.5ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 1 handbag, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 17.9ms
# Speed: 1.2ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.2ms
# Speed: 2.4ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.6ms
# Speed: 1.3ms preprocess, 22.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.9ms
# Speed: 1.5ms preprocess, 21.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 23.1ms
# Speed: 2.5ms preprocess, 23.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.1ms
# Speed: 1.5ms preprocess, 22.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.2ms
# Speed: 1.5ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.4ms
# Speed: 1.3ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 20.1ms
# Speed: 1.3ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 22.7ms
# Speed: 1.0ms preprocess, 22.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 23.2ms
# Speed: 2.1ms preprocess, 23.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.6ms
# Speed: 2.5ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 23.3ms
# Speed: 1.4ms preprocess, 23.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.3ms
# Speed: 1.3ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 20.5ms
# Speed: 1.8ms preprocess, 20.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 17.7ms
# Speed: 1.3ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 20.9ms
# Speed: 2.5ms preprocess, 20.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 23.4ms
# Speed: 1.7ms preprocess, 23.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.3ms
# Speed: 0.5ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.7ms
# Speed: 0.5ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.8ms
# Speed: 1.3ms preprocess, 21.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.4ms
# Speed: 1.1ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 1 handbag, 20.8ms
# Speed: 1.4ms preprocess, 20.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 22.2ms
# Speed: 1.2ms preprocess, 22.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 1 handbag, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 1 handbag, 1 cell phone, 17.3ms
# Speed: 1.4ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 1 handbag, 17.8ms
# Speed: 1.0ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.7ms
# Speed: 2.0ms preprocess, 21.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.6ms
# Speed: 1.2ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.4ms
# Speed: 1.5ms preprocess, 18.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.8ms
# Speed: 1.2ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 1 handbag, 21.2ms
# Speed: 2.4ms preprocess, 21.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 19.7ms
# Speed: 1.2ms preprocess, 19.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.6ms
# Speed: 1.5ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 25.2ms
# Speed: 1.3ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.9ms
# Speed: 2.6ms preprocess, 21.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.3ms
# Speed: 1.1ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.6ms
# Speed: 1.3ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.6ms
# Speed: 2.5ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 23.9ms
# Speed: 1.2ms preprocess, 23.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 1 handbag, 22.9ms
# Speed: 2.2ms preprocess, 22.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 20.2ms
# Speed: 1.9ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25.3ms
# Speed: 1.3ms preprocess, 25.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 15.7ms
# Speed: 1.3ms preprocess, 15.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.7ms
# Speed: 1.1ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 15.2ms
# Speed: 1.4ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.2ms
# Speed: 0.5ms preprocess, 22.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.5ms
# Speed: 1.2ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 trains, 15.1ms
# Speed: 1.1ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.6ms
# Speed: 1.2ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.5ms
# Speed: 1.3ms preprocess, 14.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.4ms
# Speed: 1.2ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15.5ms
# Speed: 1.1ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.4ms
# Speed: 1.5ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 21.4ms
# Speed: 1.5ms preprocess, 21.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.8ms
# Speed: 1.1ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 21.7ms
# Speed: 2.5ms preprocess, 21.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 14.0ms
# Speed: 1.7ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 19.7ms
# Speed: 2.0ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.7ms
# Speed: 2.1ms preprocess, 21.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 28.1ms
# Speed: 2.0ms preprocess, 28.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 21.8ms
# Speed: 1.0ms preprocess, 21.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.3ms
# Speed: 1.5ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.3ms
# Speed: 1.3ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.7ms
# Speed: 2.8ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.4ms
# Speed: 1.5ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 19.8ms
# Speed: 2.1ms preprocess, 19.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.8ms
# Speed: 1.3ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 22.2ms
# Speed: 1.5ms preprocess, 22.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 15.2ms
# Speed: 2.4ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 22.6ms
# Speed: 1.3ms preprocess, 22.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.9ms
# Speed: 1.3ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.6ms
# Speed: 1.3ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 15.7ms
# Speed: 1.2ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.6ms
# Speed: 2.5ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 1.3ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.3ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 1.4ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 1.4ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 1.2ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.2ms
# Speed: 1.5ms preprocess, 22.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 1.5ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 1.3ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 2.5ms preprocess, 24.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.8ms
# Speed: 1.5ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.5ms
# Speed: 1.2ms preprocess, 21.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.6ms
# Speed: 1.2ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 1.3ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 1.1ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 1.2ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 1.4ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 15.3ms
# Speed: 1.5ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.6ms
# Speed: 1.1ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.3ms
# Speed: 1.1ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21.3ms
# Speed: 2.2ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.2ms
# Speed: 2.1ms preprocess, 22.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.6ms
# Speed: 2.4ms preprocess, 22.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.1ms
# Speed: 1.2ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.7ms
# Speed: 2.4ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.8ms
# Speed: 1.2ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17.4ms
# Speed: 1.1ms preprocess, 17.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.8ms
# Speed: 1.0ms preprocess, 22.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.3ms
# Speed: 2.4ms preprocess, 16.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23.4ms
# Speed: 2.4ms preprocess, 23.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# f:\Tutorial\learn-yolo-object-detection\Project 2 - People Counter\People-Counter.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> while True:
#       <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     success, img = cap.read()
# ----> <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     imgRegion = cv2.bitwise_and(img, mask)
#       <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     imgGraphics = cv2.imread(
#       <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>         "graphics.png", cv2.IMREAD_UNCHANGED
#       <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>     )
#       <a href='vscode-notebook-cell:/f%3A/Tutorial/learn-yolo-object-detection/Project%202%20-%20People%20Counter/People-Counter.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     img = cvzone.overlayPNG(img, imgGraphics, (730, 260))
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'
